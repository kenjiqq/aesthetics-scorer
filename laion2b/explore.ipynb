# %%
import pandas as pd
import torch
import numpy as np

# %%
laion_df = pd.read_parquet("parquet/part-00000-5114fd87-297e-42b0-9d11-50f1df323dfa-c000.snappy.parquet")

# %%
laion_df = laion_df[laion_df["NSFW"] != "NSFW"].head(1000000)

# %%
laion_df.to_parquet("parquet/dataset.parquet")

# %%
laion_df
# Out:
#             SAMPLE_ID                                                URL  \
# 0        2.641080e+12  https://cdn.shopify.com/s/files/1/0017/3621/25...
# 1        1.069682e+12  http://cdn.bmwblog.com/wp-content/uploads/2016...
# 2        7.480780e+11  http://ecx.images-amazon.com/images/I/51phsP4a...
# 3        3.203431e+12  https://www.deltekproducts.com/_resources/imag...
# 5        3.696823e+12  https://www.4fnet.org/wp-content/uploads/2020/...
# ...               ...                                                ...
# 1018311  3.511209e+12  https://i.ebayimg.com/thumbs/images/g/mEEAAOSw...
# 1018312  3.392200e+12  https://ae01.alicdn.com/kf/HTB1GUnHSpXXXXaGXXX...
# 1018313  1.253136e+12  https://marathonsports.hkstore.com/pub/media/c...
# 1018314  3.798858e+12  https://img.wongnai.com/p/192x192/2020/07/26/b...
# 1018315  1.232764e+12   http://i3.ytimg.com/vi/F-Nd-qGSG1Q/mqdefault.jpg
#
#                                                       TEXT  HEIGHT  WIDTH  \
# ...
